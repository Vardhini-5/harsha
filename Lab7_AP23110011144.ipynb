# %%
import pandas as pd
from sklearn.impute import KNNImputer
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.model_selection import train_test_split
from imblearn.over_sampling import SMOTE

# %%
# !gdown 1ZdhRqYv-JizWV6DxO6C4R_k1kxPhmlF2
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1ZdhRqYv-JizWV6DxO6C4R_k1kxPhmlF2
# To: /content/multiclass.csv
# 100% 14.6k/14.6k [00:00<00:00, 32.5MB/s]

# %% [markdown]
# LOAD THE DATA

# %%
df = pd.read_csv('/content/multiclass.csv')
display(df.head())
# Out:
#    Region  Fresh  Milk  Grocery  Frozen  Detergents_Paper  Delicassen  class
# 0       3  12669  9656     7561     214              2674        1338      2
# 1       3   7057  9810     9568    1762              3293        1776      2
# 2       3   6353  8808     7684    2405              3516        7844      2
# 3       3  13265  1196     4221    6404               507        1788      1
# 4       3  22615  5410     7198    3915              1777        5185      1

# %% [markdown]
# FILL THE MISSING VALUES

# %%
imputer = KNNImputer(n_neighbors=5)
df_imputed = pd.DataFrame(imputer.fit_transform(df), columns=df.columns)
display(df_imputed.head())
# Out:
#    Region    Fresh    Milk  Grocery  Frozen  Detergents_Paper  Delicassen  \
# 0     3.0  12669.0  9656.0   7561.0   214.0            2674.0      1338.0
# 1     3.0   7057.0  9810.0   9568.0  1762.0            3293.0      1776.0
# 2     3.0   6353.0  8808.0   7684.0  2405.0            3516.0      7844.0
# 3     3.0  13265.0  1196.0   4221.0  6404.0             507.0      1788.0
# 4     3.0  22615.0  5410.0   7198.0  3915.0            1777.0      5185.0
#
#    class
# 0    2.0
# 1    2.0
# 2    2.0
# 3    1.0
# 4    1.0

# %% [markdown]
# STANDARDIZE SCALING
#
# CHECK FOR IMBALANCED DATA

# %%
display(df_encoded['class'].value_counts())
# Out:
# class
# 1    180
# 2    173
# 0     87
# Name: count, dtype: int64

# %%
scaler = StandardScaler()
numerical_cols = ['Fresh', 'Milk', 'Grocery', 'Frozen', 'Detergents_Paper', 'Delicassen']
df_encoded[numerical_cols] = scaler.fit_transform(df_encoded[numerical_cols])
display(df_encoded.head())
# Out:
#    Region     Fresh      Milk   Grocery    Frozen  Detergents_Paper  \
# 0     3.0  0.052933  0.523568 -0.041115 -0.589367         -0.043569
# 1     3.0 -0.391302  0.544458  0.170318 -0.270136          0.086407
# 2     3.0 -0.447029  0.408538 -0.028157 -0.137536          0.133232
# 3     3.0  0.100111 -0.624020 -0.392977  0.687144         -0.498588
# 4     3.0  0.840239 -0.052396 -0.079356  0.173859         -0.231918
#
#    Delicassen  class
# 0   -0.066339      1
# 1    0.089151      1
# 2    2.243293      1
# 3    0.093411      0
# 4    1.299347      0

# %% [markdown]
# COUNT OF EACH CLASS
#
# VARIENCE OF EACH FEATURE

# %%
display(X_resampled.var())
# Out:
# Region              0.596394
# Fresh               0.872072
# Milk                0.857451
# Grocery             0.861009
# Frozen              0.904352
# Detergents_Paper    0.852811
# Delicassen          0.833363
# dtype: float64

# %% [markdown]
# CONFUSION MATRIX OF FEATURES

# %%
correlation_matrix = X_resampled.corr()
display(correlation_matrix)
# Out:
#                     Region     Fresh      Milk   Grocery    Frozen  \
# Region            1.000000  0.040949  0.042133  0.013567  0.018633
# Fresh             0.040949  1.000000  0.069023 -0.040210  0.336842
# Milk              0.042133  0.069023  1.000000  0.738351  0.114011
# Grocery           0.013567 -0.040210  0.738351  1.000000 -0.047913
# Frozen            0.018633  0.336842  0.114011 -0.047913  1.000000
# Detergents_Paper  0.001758 -0.127652  0.671762  0.925822 -0.139935
# Delicassen        0.040633  0.227224  0.410616  0.217305  0.370100
#
#                   Detergents_Paper  Delicassen
# Region                    0.001758    0.040633
# Fresh                    -0.127652    0.227224
# Milk                      0.671762    0.410616
# Grocery                   0.925822    0.217305
# Frozen                   -0.139935    0.370100
# Detergents_Paper          1.000000    0.082985
# Delicassen                0.082985    1.000000

# %%
display(df['class'].value_counts())
# Out:
# class
# 2    180
# 3    173
# 1     87
# Name: count, dtype: int64

# %% [markdown]
# SPLIT DATA INTO TRAINING AND TESTING SETS

# %%
X_train, X_test, y_train, y_test = train_test_split(X_resampled, y_resampled, test_size=0.2, random_state=42, stratify=y_resampled)

print("Shape of X_train:", X_train.shape)
print("Shape of X_test:", X_test.shape)
print("Shape of y_train:", y_train.shape)
print("Shape of y_test:", y_test.shape)
# Out:
# Shape of X_train: (432, 7)
# Shape of X_test: (108, 7)
# Shape of y_train: (432,)
# Shape of y_test: (108,)

# %% [markdown]
# CORRET THE IMBALANCED DATA USING SMOTE

# %%
X = df_encoded.drop('class', axis=1)
y = df_encoded['class']

smote = SMOTE(random_state=42)
X_resampled, y_resampled = smote.fit_resample(X, y)

print("Shape of original data:", X.shape)
print("Shape of resampled data:", X_resampled.shape)
print("\nValue counts of original target variable:")
display(y.value_counts())
print("\nValue counts of resampled target variable:")
display(y_resampled.value_counts())
# Out:
# Shape of original data: (440, 7)
# Shape of resampled data: (540, 7)
#
# Value counts of original target variable:
# class
# 1    180
# 2    173
# 0     87
# Name: count, dtype: int64
# Value counts of resampled target variable:
# class
# 1    180
# 0    180
# 2    180
# Name: count, dtype: int64

# %%
import numpy as np

def knn(X,Y,queryPoint,k):
    """Predict the class label for the query point"""
    # Euclidean Distance
    dist = np.sqrt(np.sum((queryPoint-X)**2,axis=1) )

    # Storing distance and Class labels together
    distances = [(dist[i],Y[i]) for i in range(len(dist)) ]
    # sort the distances
    distances = sorted(distances)
    # Nearest/First K points
    distances = distances[:k]

    distances = np.array(distances)

    classes_counts = np.unique(distances[:,1],return_counts=True)

    index = classes_counts[1].argmax()
    pred = classes_counts[0][index]

    return int(pred),distances

# %%
pred,neighbors = knn(X_resampled, y_resampled, X_test.iloc[40],7)

print(f'k nearest neighbors with the distnace and class label : {neighbors}')

print(f'The predicted class labels: {pred}')
# Out:
# k nearest neighbors with the distnace and class label : [[0.         1.        ]
#  [1.67682541 2.        ]
#  [1.70123467 1.        ]
#  [1.78063151 1.        ]
#  [1.81021488 1.        ]
#  [1.84153681 2.        ]
#  [1.95573236 2.        ]]
# The predicted class labels: 1

# %% [markdown]
# SKlearn's KNN IMPLEMENTATION

# %%
from sklearn.neighbors import KNeighborsClassifier
import matplotlib.pyplot as plt

# %%
knn = KNeighborsClassifier(n_neighbors=5,metric='euclidean')
knn.fit(X_resampled, y_resampled)
# Out:
# KNeighborsClassifier(metric='euclidean')

# %% [markdown]
# ACCURACY OF KNN ON TEST DATA

# %%
knn.score(X_test, y_test)
# Out:
# 0.9629629629629629

# %% [markdown]
# PRECISION RECALL F1SCORE

# %%
from sklearn.metrics import classification_report

y_pred = knn.predict(X_test)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.99        36
#            1       1.00      0.89      0.94        36
#            2       0.92      1.00      0.96        36
#
#     accuracy                           0.96       108
#    macro avg       0.97      0.96      0.96       108
# weighted avg       0.97      0.96      0.96       108
